columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime as dt

# %%
t_values = [dt.strptime(d, "%Y-%m-%d %H:%M:%S") for d in df['tt']]

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(t_values,df['sp'],c='k')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.set_xlabel('year-month')
ax.set_ylabel('Surface pressure [Pa]')
# Out:
# Text(0, 0.5, 'Surface pressure [Pa]')

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(t_values,df['msl'],c='k')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.set_xlabel('year-month')
ax.set_ylabel('air_pressure_at_mean_sea_level [Pa]')
# Out:
# Text(0, 0.5, 'air_pressure_at_mean_sea_level [Pa]')

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(t_values,df['ws10'],c='k')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.set_xlabel('year-month')
ax.set_ylabel('Wind Speed [m/s]')
# Out:
# Text(0, 0.5, 'Wind Speed [m/s]')

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(t_values,df['tco3'],c='k')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.set_xlabel('year-month')
ax.set_ylabel('Total column ozone [kg m**-2]')
# Out:
# Text(0, 0.5, 'Total column ozone [kg m**-2]')

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(t_values,df['t2m'],c='k')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.set_xlabel('year-month')
ax.set_ylabel('2 metre temperature [K]')
# Out:
# Text(0, 0.5, '2 metre temperature [K]')

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(t_values,df['d2m'],c='k')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.set_xlabel('year-month')
ax.set_ylabel('2 metre dewpoint temperature [K]')
# Out:
# Text(0, 0.5, '2 metre dewpoint temperature [K]')

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(t_values,df['tcc'],c='k')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.set_xlabel('year-month')
ax.set_ylabel('Total cloud cover [0-100]')
# Out:
# Text(0, 0.5, 'Total cloud cover [0-100]')

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(t_values,df['tclw'],c='k')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.set_xlabel('year-month')
ax.set_ylabel('Total column cloud liquid water [kg m**-2]')
# Out:
# Text(0, 0.5, 'Total column cloud liquid water [kg m**-2]')

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(t_values,df['cdrem'],c='k')
ax.xaxis.set_major_formatter(mdates.DateFormatter('%y-%m'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))
ax.set_xlabel('year-month')
ax.set_ylabel('cloud droplet effective radius [um]')
# Out:
# Text(0, 0.5, 'cloud droplet effective radius [um]')

# %%
fig, axs = plt.subplots(3,4,figsize=(20, 8),gridspec_kw = {'wspace':.5, 'hspace':.5})
titles=[ [r'$\lambda=400$',r'$\lambda=425$',r'$\lambda=450$',r'$\lambda=475$'],
         [r'$\lambda=500$',r'$\lambda=525$',r'$\lambda=550$',r'$\lambda=575$'],
         [r'$\lambda=600$',r'$\lambda=625$',r'$\lambda=450$',r'$\lambda=675$']]

axs[0,0].plot(t_values,df['taua400'],c='k')
axs[0,1].plot(t_values,df['taua425'],c='k')
axs[0,2].plot(t_values,df['taua450'],c='k')
axs[0,3].plot(t_values,df['taua475'],c='r')
axs[1,0].plot(t_values,df['taua500'],c='k')
axs[1,1].plot(t_values,df['taua525'],c='k')
axs[1,2].plot(t_values,df['taua550'],c='k')
axs[1,3].plot(t_values,df['taua575'],c='k')
axs[2,0].plot(t_values,df['taua600'],c='k')
axs[2,1].plot(t_values,df['taua625'],c='k')
axs[2,2].plot(t_values,df['taua650'],c='k')
axs[2,3].plot(t_values,df['taua675'],c='k')
for i in range(3):
    for j in range(4):
         axs[i,j].xaxis.set_major_formatter(mdates.DateFormatter('%m'))
         axs[i,j].xaxis.set_major_locator(mdates.MonthLocator(interval=1))
         axs[i,j].set_ylim([0,0.5])
         axs[i,j].set_title(titles[i][j])
for i in range(3):
    axs[i,0].set_ylabel(r'$[-]$')
for j in range(4):
    axs[2,j].set_xlabel('month')
fig.suptitle('aerosol optical thickness')
# Out:
# Text(0.5, 0.98, 'aerosol optical thickness')

# %%
fig, axs = plt.subplots(3,4,figsize=(20, 8),gridspec_kw = {'wspace':.5, 'hspace':.5})
titles=[ [r'$\lambda=400$',r'$\lambda=425$',r'$\lambda=450$',r'$\lambda=475$'],
         [r'$\lambda=500$',r'$\lambda=525$',r'$\lambda=550$',r'$\lambda=575$'],
         [r'$\lambda=600$',r'$\lambda=625$',r'$\lambda=450$',r'$\lambda=675$']]

axs[0,0].plot(t_values,df['asymp400'],c='k')
axs[0,1].plot(t_values,df['asymp425'],c='k')
axs[0,2].plot(t_values,df['asymp450'],c='k')
axs[0,3].plot(t_values,df['asymp475'],c='r')
axs[1,0].plot(t_values,df['asymp500'],c='k')
axs[1,1].plot(t_values,df['asymp525'],c='k')
axs[1,2].plot(t_values,df['asymp550'],c='k')
axs[1,3].plot(t_values,df['asymp575'],c='k')
axs[2,0].plot(t_values,df['asymp600'],c='k')
axs[2,1].plot(t_values,df['asymp625'],c='k')
axs[2,2].plot(t_values,df['asymp650'],c='k')
axs[2,3].plot(t_values,df['asymp675'],c='k')
for i in range(3):
    for j in range(4):
         axs[i,j].xaxis.set_major_formatter(mdates.DateFormatter('%m'))
         axs[i,j].xaxis.set_major_locator(mdates.MonthLocator(interval=1))
         axs[i,j].set_ylim([0.6,0.8])
         axs[i,j].set_title(titles[i][j])
for i in range(3):
    axs[i,0].set_ylabel(r'$[-]$')
for j in range(4):
    axs[2,j].set_xlabel('month')
fig.suptitle('aerosol asymmetry parameter [um]')
# Out:
# Text(0.5, 0.98, 'aerosol asymmetry parameter [um]')

# %%
fig, axs = plt.subplots(3,4,figsize=(20, 8),gridspec_kw = {'wspace':.5, 'hspace':.5})
titles=[ [r'$\lambda=400$',r'$\lambda=425$',r'$\lambda=450$',r'$\lambda=475$'],
         [r'$\lambda=500$',r'$\lambda=525$',r'$\lambda=550$',r'$\lambda=575$'],
         [r'$\lambda=600$',r'$\lambda=625$',r'$\lambda=450$',r'$\lambda=675$']]

axs[0,0].plot(t_values,df['ssalb400'],c='k')
axs[0,1].plot(t_values,df['ssalb425'],c='k')
axs[0,2].plot(t_values,df['ssalb450'],c='k')
axs[0,3].plot(t_values,df['ssalb475'],c='r')
axs[1,0].plot(t_values,df['ssalb500'],c='k')
axs[1,1].plot(t_values,df['ssalb525'],c='k')
axs[1,2].plot(t_values,df['ssalb550'],c='k')
axs[1,3].plot(t_values,df['ssalb575'],c='k')
axs[2,0].plot(t_values,df['ssalb600'],c='k')
axs[2,1].plot(t_values,df['ssalb625'],c='k')
axs[2,2].plot(t_values,df['ssalb650'],c='k')
axs[2,3].plot(t_values,df['ssalb675'],c='k')
for i in range(3):
    for j in range(4):
         axs[i,j].xaxis.set_major_formatter(mdates.DateFormatter('%m'))
         axs[i,j].xaxis.set_major_locator(mdates.MonthLocator(interval=1))
         axs[i,j].set_ylim([0.9,1.])
         axs[i,j].set_title(titles[i][j])
for i in range(3):
    axs[i,0].set_ylabel(r'$[-]$')
for j in range(4):
    axs[2,j].set_xlabel('month')
fig.suptitle('aerosol single scattering albedo [-]')
# Out:
# Text(0.5, 0.98, 'aerosol single scattering albedo [-]')

# %%
fig, axs = plt.subplots(3,4,figsize=(20, 8),gridspec_kw = {'wspace':.5, 'hspace':.5})
titles=[ [r'$\lambda=400$',r'$\lambda=425$',r'$\lambda=450$',r'$\lambda=475$'],
         [r'$\lambda=500$',r'$\lambda=525$',r'$\lambda=550$',r'$\lambda=575$'],
         [r'$\lambda=600$',r'$\lambda=625$',r'$\lambda=450$',r'$\lambda=675$']]

axs[0,0].plot(t_values,(df['ed_400']+df['es_400'])/25.,c='k')
axs[0,1].plot(t_values,(df['ed_425']+df['es_425'])/25.,c='k')
axs[0,2].plot(t_values,(df['ed_450']+df['es_450'])/25.,c='k')
axs[0,3].plot(t_values,(df['ed_475']+df['es_475'])/25.,c='k')
axs[1,0].plot(t_values,(df['ed_500']+df['es_500'])/25.,c='k')
axs[1,1].plot(t_values,(df['ed_525']+df['es_525'])/25.,c='k')
axs[1,2].plot(t_values,(df['ed_550']+df['es_550'])/25.,c='k')
axs[1,3].plot(t_values,(df['ed_575']+df['es_575'])/25.,c='k')
axs[2,0].plot(t_values,(df['ed_600']+df['es_600'])/25.,c='k')
axs[2,1].plot(t_values,(df['ed_625']+df['es_625'])/25.,c='k')
axs[2,2].plot(t_values,(df['ed_650']+df['es_650'])/25.,c='k')
axs[2,3].plot(t_values,(df['ed_675']+df['es_675'])/25.,c='k')
for i in range(3):
    for j in range(4):
         axs[i,j].xaxis.set_major_formatter(mdates.DateFormatter('%m'))
         axs[i,j].xaxis.set_major_locator(mdates.MonthLocator(interval=1))
         axs[i,j].set_ylim([0,1.7])
         axs[i,j].set_title(titles[i][j])
for i in range(3):
    axs[i,0].set_ylabel(r'$Wm^{-2}nm^{-1}$')
for j in range(4):
    axs[2,j].set_xlabel('month')
